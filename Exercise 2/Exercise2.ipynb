# %% [markdown]
# # Exercise 2
#
# Simple Linear Regression
#
# **Instructions:**
#
# Build a Simple Linear Regression model to study the linear relationship between the years of experience and salary.
#
# <img src="https://media2.giphy.com/media/67ThRZlYBvibtdF9JH/200w.gif?cid=6c09b952x78udp8ynvf71q2iximtwq0egwludug1qo7qgla2&ep=v1_gifs_search&rid=200w.gif&ct=g">

# %% [markdown]
# 1. Import the necessary packages

# %%
# put your answer her

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 2. Load the salary.csv file

# %%
# put your answer here
df = pd.read_csv("salary.csv")
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.2   39344
# 1              1.4   46206
# 2              1.6   37732
# 3              2.1   43526
# 4              2.3   39892

# %% [markdown]
# # New section

# %% [markdown]
# 3. Print the first 5 rows of the dataset

# %%
# put your answer here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %% [markdown]
# 4. Display the general information of the dataframe

# %%
# put your answer here

df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %% [markdown]
# 5. Visualize the data by creating a scatter plot

# %%
# put your answer here

df.plot(x='YearsExperience',y='Salary',kind='scatter')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# 6. Split the dataset into a training set and test set

# %%
# put answer here

X = df['YearsExperience'].values
y = df['Salary'].values

# %% [markdown]
# 7. Create an new instance of a linear regression model

# %%
# put your answer here

X = X.reshape(-1,1)

y = y.reshape(-1,1)

# %% [markdown]
# 8. Train and test the model using the training set and test set

# %%
# put your answer here

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# 9. Print the equation of the line
#
# - Display the slope
# - Display the intercept
# - Display the equation of the line

# %%
# put your answer here

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (20, 1)
# (20, 1)
# (10, 1)
# (10, 1)

# %% [markdown]
# 10. Draw the Regression Line

# %%
plt.scatter(X, y, color = 'blue', label='Data Points')
plt.plot(X_test, y_pred, color = 'red', linewidth=3, label = 'Regression Line')
plt.title('Relationship between YearsExperience and Salary')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# 11. Compute the Sum of Square Error (SSE)

# %%
df1.head()
# Out:
#    Actual_salary  Predicted_salary
# 0         112636     115815.307562
# 1          67939      71512.925348
# 2         113813     102618.853286
# 3          83089      75283.340855
# 4          64446      55488.659440
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Actual_salary'].plot(kind='hist', bins=20, title='Actual_salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Predicted_salary'].plot(kind='hist', bins=20, title='Predicted_salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Actual_salary', y='Predicted_salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['Actual_salary'].plot(kind='line', figsize=(8, 4), title='Actual_salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['Predicted_salary'].plot(kind='line', figsize=(8, 4), title='Predicted_salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Actual_salary'].plot(kind='hist', bins=20, title='Actual_salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['Predicted_salary'].plot(kind='hist', bins=20, title='Predicted_salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='index', y='Actual_salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Actual_salary', y='Predicted_salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Actual_salary']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Actual_salary')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Predicted_salary']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Predicted_salary')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Actual_salary'].plot(kind='line', figsize=(8, 4), title='Actual_salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Predicted_salary'].plot(kind='line', figsize=(8, 4), title='Predicted_salary')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
sum_of_squared_errors = str(np.sum(np.square(df1['Actual_salary'] - df1['Predicted_salary'])))

print('residual sum of squares is : ', sum_of_squared_errors)
# Out:
# residual sum of squares is :  353018988.87134814

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.955306313804495
